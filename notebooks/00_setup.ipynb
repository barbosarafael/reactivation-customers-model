# %% [markdown]
# # 0. Instalando as dependências

# %%
# %pip install -r ../requirements.txt

# %%
dbutils.library.restartPython()

# %%
import pandas as pd
import numpy as np
import sklearn
import mlflow
import yaml

print(f"Spark version: {spark.version}")
print("Setup finalizado.")
